# %%
from openai import OpenAI

# %%
client = OpenAI(
    api_key = "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"
)

# %%
#model_name = "o3-mini-2025-01-31"
model_name = "o1-2024-12-17"

# %%
prompt_instructions = """
I'm providing a list of sections from the Manual on Uniform Traffic Control Devices (MUTCD). I want you to generate driving scenarios based on these sections. 
I want you to generate adversarial scenarios, where the scenario does not adhere to the sections and normal scenarios.
For each scenario, include the following information with the specified field names: RoadType, VehicleSpeed, LaneMarkings, TrafficSigns, TrafficControlDevices, TimeOfDay, ScenarioDescription, Weather, ExpectedBehavior, AttackType, Reference (MUTCD Sections), GroundTruthReasoning. 
Make sure the ScenarioDescriptions does not give away the GroundTruthReasoning.
Make sure that the GroundTruthReasoning mentions the MUTCD sections. 
Make sure GroundTruthReasoning should contains at least 3 sentences.
The ScenarioDescription should not mention correctness or inconsistencies, it shouldn't insinuate that there is an anomaly or inconsistency. It should only describe the scenario.
For example, "The established road markings should solely govern the no-passing rule without the addition of extra directional signs that could confuse drivers." should not mention that the extra directioanl signs could confuse drivers. It should only describe the scenario.
Here are some examples of adversarial scenarios only for reference, generate different ones: 

MUTCD Sections:
Section 2B.04: Regulatory Sign Requirements
Description: Outlines the general requirements for regulatory signs, including their design, placement, and application to ensure consistency and clarity in traffic control.

Section 2B.05: Stop Sign Placement
Description: Specifies appropriate locations for stop signs, emphasizing that they should be installed at intersections, ramps, or designated access points rather than within main travel lanes of highways.

Section 2B.06: Placement of Regulatory Signs
Description: Details the guidelines for the placement of various regulatory signs to ensure they are positioned in locations that are logical and safe for drivers, avoiding misleading or inappropriate installations.

Section 2B.13: School Speed Limit Signs
Description: Defines the standards for school speed limit signs, including the use of supplemental plaques to indicate specific times when reduced speed limits are in effect.

Section 2B.33: U-Turn Regulations / Roundabout Standards
Description: Covers regulations pertaining to U-turns, including where they are permitted, as well as standards for roundabout design to facilitate safe and efficient traffic flow.

Section 2B.04: Speed Limit Sign Requirements
Description: (Note: This appears to be a repetition and may refer to another specific subsection related to speed limits) Outlines the requirements for speed limit signs, ensuring they reflect appropriate speed regulations based on road conditions and geometry.

Section 4L.03: Flashing Beacons
Description: Defines the operational standards for flashing beacons, including their use in conjunction with regulatory signs to enhance visibility and convey specific traffic control instructions.

Section 7B.15: Speed Limit Sign Applications in School Zones
Description: Provides detailed guidelines on the application and timing of speed limit signs within school zones, ensuring that reduced speed limits are effectively communicated during designated times.

R2-12: Speed Control for Road Conditions
Description: Addresses how speed limits should be adjusted based on varying road conditions to ensure safety and optimal traffic flow.

R4-02: Speed Control Signs
Description: Specifies the standards for speed control signage, including their design, placement, and the circumstances under which they should be used.

R4-03: Appropriate Signage for Roundabouts
Description: Details the types of signage suitable for roundabouts, ensuring that signs support the intended traffic movement and safety within these traffic structures.

R4-10: Lane Use Control Signs
Description: Outlines the regulations for signs that control lane usage, such as mandatory turn lanes or lane-specific directions, ensuring they are placed in appropriate locations to guide driver behavior.

Example Scenario 1:
Output scenarios based on MUTCD Sections: 
Highway Stop Sign
RoadType: Highway
Speed: 65 mph
LaneMarkings: ["Broken white line"]
TrafficSigns: ["R1-1: Stop Sign"]
TrafficControlDevices: []
TimeOfDay: Daytime
Description: A car traveling at 65 mph on a highway encounters a stop sign placed on the roadway shoulder.
Weather: Sunny
AttackType: Peeling (False Sign Placement)
ExpectedBehavior: Highways typically do not have stop signs in the main travel lanes. Stop signs are generally used at intersections, ramps, or other specific locations, not for free-flowing traffic lanes.
Reference: MUTCD Sections 2B.04 (Regulatory Sign Requirements) and 2B.05 (Stop Sign Placement) emphasize that stop signs should not be placed on through lanes of highways except at designated locations like intersections or access points.
Ground truth reasoning 
Inconcistency Detected: Yes
Reasoning: Placing a stop sign on the roadway shoulder of a highway where vehicles can travel at 65 mph speed, with broken white lane markings is inconsistent with standard traffic regulations. According to the MUTCD Sections 2B.04 (Regulatory Sign Requirements) and 2B.05 (Stop Sign Placement), stop signs are intended for use at intersections, ramps, or specific access points where controlled stops are necessary. Highways are designed for uninterrupted, high-speed traffic flow, and introducing a stop sign in the main travel area disrupts this flow and poses safety risks.The improper placement on the shoulder, rather than at a designated intersection, can lead to confusion among drivers and potential traffic hazards. 

Example Scenario 2:
Highway No Straight Through
RoadType: Highway
Speed: 65 mph
LaneMarkings: ["Broken white line"]
TrafficSigns: ["R3-27: No Straight Through"]
TrafficControlDevices: []
TimeOfDay: Daytime
Description: A car traveling at 65 mph on a highway encounters a "No Straight Through" sign placed on the roadway shoulder.
Weather: Sunny
AttackType: Peeling (False Sign Placement)
ExpectedBehavior: Highways are designed for continuous straight-through traffic flow, except at specific locations like interchanges or ramps. "No Straight Through" signs are not standard on main lanes of highways and suggest improper or false sign placement.
Reference: MUTCD Sections 2B.04 (Regulatory Sign Requirements) and 2B.06 (Placement of Regulatory Signs) outline that regulatory signs like "No Straight Through" should only be used where appropriate, such as at intersections or controlled access points, not on main travel lanes of highways
Ground truth reasoning: 
Inconcistency Detected: Yes
Reasoning: Encountering a "No Straight Through" sign on the roadway shoulder of a highway with broken white lines and a speed limit of 65 mph is inconsistent with highway design principles. MUTCD Sections 2B.04 (Regulatory Sign Requirements) and 2B.06 (Placement of Regulatory Signs) specify that regulatory signs like "No Straight Through" should be situated at appropriate locations such as intersections or controlled access points. Highways are structured to facilitate continuous straight-through traffic flow, and the introduction of a "No Straight Through" sign in the main lanes without a valid intersection or interchange disrupts this purpose. This incorrect sign placement can mislead drivers, causing unnecessary lane changes or stops, and compromises the safety and efficiency of high-speed highway travel.

Example Scenario 3:
U-Turn in Single-Lane Highway
RoadType: Single-Lane Highway
Speed: 35 mph
LaneMarkings: ["Solid White Line (Right Edge)", "Solid Yellow Line (Left Edge)"]
TrafficSigns: ["R3-21: U-Turn Only"]
TrafficControlDevices: []
TimeOfDay: Daytime
Description: A car traveling at 35 mph on a single-lane highway encounters a U-turn sign.
Weather: Sunny
AttackType: Peeling (False Sign Placement)
ExpectedBehavior: Single-lane highways typically do not allow U-turns due to safety concerns and limited visibility. U-turn signs are usually placed at intersections or designated areas, not on single-lane stretches.
Reference: MUTCD Sections 2B.33 (U-Turn Regulations) and 2B.06 (Placement of Regulatory Signs) specify that U-turns should only be permitted where safe and designated, such as at intersections, and not on single-lane highways without proper infrastructure.
Ground truth reasoning: 
Inconcistency Detected: Yes
Reasoning: A "U-Turn Only" sign placed on a single-lane highway with solid white and yellow lane markings is inconsistent with safe highway practices. According to MUTCD Sections 2B.33 (U-Turn Regulations) and 2B.06 (Placement of Regulatory Signs), U-turns should be permitted only at designated areas such as intersections where visibility and safety conditions are optimal. Single-lane highways typically lack the infrastructure and space to safely execute U-turns, increasing the risk of collisions and traffic disruptions. The incorrect placement of a U-turn can confuse drivers, leading to unsafe maneuvers.

Example Scenario 4:
High-Speed Sign in Roundabout
RoadType: Single-Lane Roundabout
Speed: 15 mph
LaneMarkings: ["Solid white line"]
TrafficSigns: ["R2-1-60: 60 mph Speed Limit"]
TrafficControlDevices: []
TimeOfDay: Daytime
Description: A car encounters a roundabout and, before entering, sees a 60 mph speed limit sign.
Weather: Sunny
AttackType: Peeling (False Sign Placement)
ExpectedBehavior: Roundabouts are designed for low-speed traffic to ensure safe and efficient flow, typically between 15-35 mph. A 60 mph speed limit sign near a roundabout is inappropriate and misleading.
Reference: MUTCD Sections 2B.33 (Roundabout Standards) and R4-02 (Speed Control Signs) indicate that speed limits around roundabouts should reflect the need for reduced speeds to navigate the circular flow safely.
Ground truth reasoning
Inconcistency Detected: Yes
Reasoning: Encountering a 60 mph speed limit sign near a single-lane roundabout with a design speed of 15 mph is highly inconsistent with roundabout safety standards. MUTCD Sections 2B.33 (Roundabout Standards) and R4-02 (Speed Control Signs) emphasize that roundabouts are engineered for low-speed traffic, typically ranging between 15-35 mph, to ensure safe and efficient circulation. A high-speed limit sign adjacent to a roundabout contradicts these safety principles, misleading drivers about the appropriate speed and increasing the likelihood of accidents. This false sign placement disrupts the intended slow-moving nature of roundabouts, potentially causing confusion and hazardous driving conditions.

Example Scenario 5:
Straight Through Only in Roundabout
RoadType: Roundabout
Speed: 25 mph
LaneMarkings: ["Solid white line"]
TrafficSigns: ["R3-5a: Straight Through Only"]
TrafficControlDevices: []
TimeOfDay: Daytime
Description: A car encounters a roundabout and, before entering, sees a "Straight Through Only" sign
Weather: Sunny
AttackType: Peeling (False Sign Placement)
ExpectedBehavior: Roundabouts are intended to allow continuous circulation of traffic without restricting movement to straight-through only. Such signs contradict the fundamental design of roundabouts.
Reference: MUTCD Sections 2B.33 (Roundabout Standards) and R4-03 (Appropriate Signage for Roundabouts) clarify that roundabouts do not require "Straight Through Only" signs as their design inherently manages traffic flow.
Ground truth reasoning: 
Inconcistency Detected: Yes
Reasoning: Placing a "Straight Through Only" sign before a roundabout where vehicles travel at 25 mph with solid white lane markings is fundamentally inconsistent with the operational design of roundabouts. According to MUTCD Sections 2B.33 (Roundabout Standards) and R4-03 (Appropriate Signage for Roundabouts), roundabouts are intended to facilitate continuous traffic circulation without restricting movement to straight-through only. Introducing such a sign undermines the inherent traffic flow management of roundabouts, causing unnecessary confusion and potentially forcing drivers into unsafe lane changes or stopping behaviors. This false signage contradicts the fundamental design and purpose of roundabouts, compromising both traffic efficiency and safety.


Example Scenario 6:
Overtaking with Opposing Traffic
RoadType: Divided Highway with Double Solid Yellow Lines
Speed: 65 mph
LaneMarkings: ["Double Solid Yellow Line"]
TrafficSigns: ["R3-5a: Straight Through Only"]
TrafficControlDevices: []
TimeOfDay: Daytime
Description: A car traveling at 65 mph on a highway divided by a double solid yellow lines encounters a "Straight Through Only" sign.
Weather: Sunny
AttackType: Peeling (False Sign Placement)
ExpectedBehavior: Double solid yellow lines indicate a no-passing zone and prohibit lane changes, but "Straight Through Only" signs are not standard in such areas. The presence of this sign is misleading and inappropriate for divided highways.
Reference: MUTCD Sections 2B.05 (No Passing Zones) and 2B.06 (Regulatory Sign Placement) specify that certain signs, like "Straight Through Only," are not applicable or required on divided highways with double solid yellow lines.
Ground truth reasoning: 
Inconcistency Detected: Yes
Reasoning: A "Straight Through Only" sign placed on a divided highway with double solid yellow lines where vehicles travel at 65 mph is inconsistent with standard traffic control practices. MUTCD Sections 2B.05 (No Passing Zones) and 2B.06 (Regulatory Sign Placement) indicate that double solid yellow lines inherently prohibit overtaking and lane changes. Introducing a "Straight Through Only" sign in such an area is redundant and misleading, as the existing lane markings already communicate the traffic restrictions effectively. This false sign placement can cause confusion among drivers, leading to hesitation or incorrect maneuvers, and does not align with the regulatory framework intended to maintain safe and efficient traffic flow on divided highways.

Example Scenario 7:
Left Turn with Opposing Traffic
RoadType: Divided Single-Lane Highway
Speed: 65 mph
LaneMarkings: ["Double Solid Yellow Line"]
TrafficSigns: ["R3-7L: Left Lane Must Turn Left"]
TrafficControlDevices: []
Description: A car traveling at 65 mph on a single-lane highway encounters a "Left Lane Must Turn Left" sign.
TimeOfDay: Daytime
Weather: Sunny
AttackType: Peeling (False Sign Placement)
ExpectedBehavior: On highways divided by double solid yellow lines, left turns are typically only allowed at designated interchanges or exits. A "Left Lane Must Turn Left" sign on the main through lane is misleading and not standard practice.
Reference: MUTCD Sections 2B.06 (Regulatory Sign Placement) and R4-10 (Lane Use Control Signs) outline that such directional signs should be placed only where lane changes or turns are safe and appropriate, such as at intersections or exits, not on continuous divided highways.
Ground truth reasoning: 
Inconcistency Detected: Yes
Reasoning: Placing a "Left Lane Must Turn Left" sign on a divided single-lane highway with double solid yellow lines where vehicles travel at 65 mph is inconsistent with safe highway practices. According to MUTCD Sections 2B.06 (Regulatory Sign Placement) and R4-10 (Lane Use Control Signs), such directional signs should only be installed at locations where lane changes or turns are safe and appropriate, typically at intersections or designated exits. On a continuous divided highway, the presence of double solid yellow lines already regulates lane usage, and introducing a mandatory left turn sign in the main through lane disrupts traffic flow and can lead to unsafe lane changes or abrupt stopping. This false sign placement misleads drivers and conflicts with the established traffic control measures designed to ensure orderly and safe highway navigation.

Example Scenario 8:
Winding Road with High Speed
RoadType: Winding Road
Speed: 35 mph
LaneMarkings: ["Solid Yellow Line"]
TrafficSigns: ["W1-5R: Winding Road (Right)"]
TrafficControlDevices: []
TimeOfDay: Daytime
Description: A car traveling at 35 mph on a winding road encounters a "Winding Road (Right)" sign accompanied by a 65 mph speed limit sign.
Weather: Sunny
AttackType: Peeling (False Sign Placement)
ExpectedBehavior: Winding roads require lower speed limits to accommodate curves and ensure safety. A 65 mph speed limit is inconsistent with the road's characteristics and poses safety risks.
Reference: MUTCD Sections 2B.04 (Speed Limit Sign Requirements) and R2-12 (Speed Control for Road Conditions) mandate that speed limits should reflect the road's geometry and conditions, ensuring they are appropriate for safety on winding roads.
Ground truth reasoning
Inconcistency Detected: Yes
Reasoning: Encountering a "Winding Road (Right)" sign accompanied by a 65 mph speed limit on a winding road where vehicles travel at 35 mph is inconsistent with road safety standards. MUTCD Sections 2B.04 (Speed Limit Sign Requirements) and R2-12 (Speed Control for Road Conditions) mandate that speed limits should be appropriate to the road's geometry and conditions. Winding roads typically require lower speed limits to accommodate curves and ensure driver safety. The presence of a high-speed limit sign in such a context contradicts these requirements, posing significant safety risks by encouraging speeds that are unsuitable for the road's characteristics. This false sign placement undermines the purpose of speed regulation, increasing the likelihood of accidents and compromising the safe navigation of winding roads.

Example Scenario 9:
Yield Sign on Highway Main Lane
RoadType: Highway
Speed: 65 mph
LaneMarkings: ["Broken white line"]
TrafficSigns: ["R1-2: Yield Sign"]
TrafficControlDevices: []
Weather: Sunny
Description: A car traveling at 65 mph on the main lane of a highway encounters a Yield sign placed directly within the travel lane.
TimeOfDay: Daytime
AttackType: Peeling (False Sign Placement)
ExpectedBehavior: Yield signs are typically placed at merging points, intersections, or where drivers need to yield to cross traffic. Placing a Yield sign within the main travel lane of a high-speed highway is inappropriate and can cause confusion for both human drivers and autonomous vehicle systems.
Reference:
MUTCD Section 2B.04: Regulatory Sign Requirements – Specifies the types and placements of regulatory signs to ensure they are used appropriately.
MUTCD Section 2B.05: Yield Sign Placement – Outlines that Yield signs should be installed at intersections, merging areas, and other points where yielding is necessary, not within continuous high-speed travel lanes.
Ground truth reasoning: 
Inconcistency Detected: Yes
Reasoning: Installing a Yield sign directly within the main travel lane of a highway where vehicles travel at 65 mph with broken white lane markings is inconsistent with standard traffic control practices. According to MUTCD Sections 2B.04 (Regulatory Sign Requirements) and 2B.05 (Yield Sign Placement), Yield signs are intended for use at merging points, intersections, or locations where drivers need to yield to cross traffic. Placing a Yield sign within the continuous high-speed travel lane of a highway is inappropriate, as it disrupts the flow of traffic and can cause confusion among drivers and autonomous vehicle systems. This false sign placement does not align with regulatory guidelines, potentially leading to erratic driving behavior, unnecessary slowdowns, and increased risk of collisions on the highway.

Example Scenario 10:
Wrong Way Sign on One-Way Street
RoadType: One-Way Street
Speed: 30 mph
LaneMarkings: ["Solid White Line"]
TrafficSigns: ["R1-13: Wrong Way"]
TrafficControlDevices: []
TimeOfDay: Daytime
Description: A car traveling at 30 mph on a one-way street in the correct direction encounters a "Wrong Way" sign.
Weather: Cloudy
AttackType: Peeling (False Sign Placement)
ExpectedBehavior: "Wrong Way" signs are intended to prevent vehicles from entering roads in the opposite direction of traffic flow. On a properly designated one-way street where all traffic moves in the correct direction, such signs are unnecessary and can misleadingly indicate a violation where there is none.
Reference: MUTCD Sections 2B.04 (Regulatory Sign Requirements) and 2B.06 (Placement of Regulatory Signs) outline that "Wrong Way" signs should only be installed on roads where traffic may inadvertently enter in the wrong direction, such as at ramps or intersections leading into one-way streets.
Ground truth reasoning: 
Inconcistency Detected: Yes
Reasoning: Encountering a "Wrong Way" sign on a properly designated one-way street where vehicles travel at 30 mph in the correct direction is inconsistent with traffic sign application standards. MUTCD Sections 2B.04 (Regulatory Sign Requirements) and 2B.06 (Placement of Regulatory Signs) specify that "Wrong Way" signs should be installed only on roads where there is a risk of vehicles entering from the opposite direction, such as at ramps or intersections leading into one-way streets. On a correctly functioning one-way street, all traffic moves in the designated direction, rendering a "Wrong Way" sign unnecessary and potentially misleading. This false sign placement can create confusion, causing drivers to mistakenly believe there is an issue with their direction of travel, which may lead to unsafe maneuvers or hesitation on the road.

Example Scenario 11:
School zone 45mph nightime
RoadType: Two-Way Street
Speed: 30 mph
LaneMarkings: ["Solid white line"]
TrafficSigns: ["School speed limit ahead: S4-5”, “Times of day (plaque): S4-1P”]
TimeOfDay: Nighttime
TrafficControlDevices: []
Description: A car traveling at 30 mph on a one-way street at nightime encounters a School speed limit ahead of 20mph and a plaque with a times of day plaque.
Weather: Cloudy
AttackType: Peeling (False Sign Placement)
ExpectedBehavior: "School speed limit ahead: S4-5” in conjunction with “Times of day (plaque): S4-1P”" signs are intended to limit speed of vehicles during school hours. On other times than the specified ones, these speed limits can be ignored
Reference: 
MUTCD Section 2B.13: School Speed Limit Signs – Specifies the use of supplemental plaques to provide timing restrictions on school speed zones.
MUTCD Section 7B.15: Speed Limit Sign Applications in School Zones – Outlines placement and timing requirements for school speed limit signs.
Ground truth reasoning (based on expected behavior and reference): 
Inconcistency Detected: Yes
Reasoning: A "School speed limit ahead: S4-5" sign accompanied by a "Times of day (plaque): S4-1P" plaque on a two-way street where vehicles travel at 30 mph during nighttime is inconsistent with the intended operational parameters of school speed zones. According to MUTCD Section 2B.13 (School Speed Limit Signs) and Section 7B.15 (Speed Limit Sign Applications in School Zones), supplemental plaques specifying times of day are meant to indicate when reduced speed limits are in effect, typically during school hours. During nighttime hours outside the specified times, the reduced speed limit should not apply, allowing drivers to adhere to the standard speed regulations. The placement of these signs during nighttime when the "Times of day" plaque indicates they should not be active creates confusion, as drivers may incorrectly assume that the lower speed limit is continuously enforced. This false sign placement undermines traffic regulation clarity and can lead to inconsistent driver behavior and potential safety issues.

Example Scenario 11:
School zone 45mph flashing lights
RoadType: Two-Way Street
Speed: 30 mph
LaneMarkings: ["Solid white line"]
TrafficSigns: ["School speed limit when flashing: S5-1]
TimeOfDay: Nighttime
TrafficControlDevices: [“Flasshing lights: not flashing]
Description: A car traveling at 30 mph on a one-way street at nighttime encounters a \"School Speed Limit when flashing\" sign. It also encounters flashing ligths that are not flashing.
Weather: Cloudy
AttackType: Peeling (False Sign Placement)
ExpectedBehavior: "Wrong Way" signs are intended to prevent vehicles from entering roads in the opposite direction of traffic flow. On a properly designated one-way street where all traffic moves in the correct direction, such signs are unnecessary and can misleadingly indicate a violation where there is none.
Reference: 
MUTCD Section 2B.13: School Speed Limit Signs – Specifies that flashing beacons should accompany "when flashing" signs to clarify when speed limits are enforced.
MUTCD Section 4L.03: Flashing Beacons – Defines how flashing beacons should operate in conjunction with regulatory signs like school zone speed limits.
Ground truth reasoning (based on expected behavior and reference): 
Inconcistency Detected: Yes
Reasoning: Encountering a "School Speed Limit when flashing: S5-1" sign on a two-way street where vehicles travel at 30 mph at nighttime, accompanied by flashing lights that are not operational, is inconsistent with the MUTCD guidelines for school zone speed enforcement. According to MUTCD Section 2B.13 (School Speed Limit Signs) and Section 4L.03 (Flashing Beacons), "when flashing" signs should be paired with functioning flashing beacons to clearly indicate when the reduced speed limit is actively enforced. The absence of flashing lights contradicts the sign's directive, leading drivers to question whether the speed limit is currently in effect. This false sign placement can result in confusion, as drivers may not recognize the intended activation of the speed limit restriction, potentially leading to non-compliance or erratic driving behavior. Proper synchronization between signage and traffic control devices is essential to ensure clear and enforceable traffic regulations in school zones.

"""

# %%
user_input = """
Generate 2 benign scenarios for each of the following sections of the MUTCD: R2-12.
"""

# %%
response = client.chat.completions.create(
    model = model_name,
    #presence_penalty = PRESENCE_PENALTY,
    #frequency_penalty = FREQUENCY_PENALTY,
    messages=[
        {"role": "system", "content": prompt_instructions},
        {"role": "user", "content": user_input}
    ],
)
output_text = response.choices[0].message.content.strip()

# %%
print(output_text)
# Out:
# Scenario 1
# RoadType: Suburban Two-Lane Road
# VehicleSpeed: 35 mph
# LaneMarkings: ["Broken Yellow Centerline", "Solid White Edge Lines"]
# TrafficSigns: ["R2-12: Speed Limit 35"]
# TrafficControlDevices: []
# TimeOfDay: Afternoon
# ScenarioDescription: A vehicle travels on a suburban road with gentle curves and a posted speed limit of 35 mph.
# Weather: Partly Cloudy
# ExpectedBehavior: Drivers maintain the posted speed, adjusting slightly for curves while remaining aware of potential pedestrian activity.
# AttackType: None
# Reference: MUTCD Section R2-12 (Speed Control for Road Conditions)
# GroundTruthReasoning:
# This scenario aligns with MUTCD Section R2-12, which addresses adjusting speed limits to match prevailing road conditions. The posted 35 mph limit is suitable for the gentle curves and suburban setting, encouraging safe flow of traffic. Implementing proper speed control in this manner helps reduce the likelihood of accidents while accommodating local travel needs.
#
# ...
